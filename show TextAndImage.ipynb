# %%
import matplotlib.pyplot as plt
import PIL
import pickle

# %%
img = plt.imread('data/COCO-Text/train2014/COCO_train2014_000000234956.jpg')

# %%
img.shape
# Out:
# (426, 640, 3)

# %%
plt.figure(figsize=(10,10))
plt.plot(xpoint, ypoint, linewidth = 3, color='r')
plt.imshow(img)
plt.axis
# Out:
# <function matplotlib.pyplot.axis(*v, **kwargs)>

# %%
from data_cocotext import GTUtility

with open('gt_util_cocotext_val.pkl', 'rb') as f:
    gt_util_val = pickle.load(f)

# %%
gt_util_val.image_names.index('COCO_train2014_000000234956.jpg')
# Out:
# 1640

# %%
boxes = gt_util_val.data[1640]

# %%
a = boxes[0][:-1]
a
# Out:
# array([0.80631447, 0.63145542, 0.86384851, 0.63145542, 0.86384851,
#        0.66454399, 0.80631447, 0.66454399])

# %%
xpoint = a[0::2]
ypoint = a[1::2]

# %%
boxes[0]
# Out:
# array([0.80631447, 0.63145542, 0.86384851, 0.63145542, 0.86384851,
#        0.66454399, 0.80631447, 0.66454399, 1.        ])

# %%
import numpy as np

# %%
np.delete(boxes[0], [0,1], 0)
# Out:
# array([0.86384851, 0.63145542, 0.86384851, 0.66454399, 0.80631447,
#        0.66454399, 1.        ])
