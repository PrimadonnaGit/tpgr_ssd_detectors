# %%
import numpy as np

from utils.training import plot_log
# Out:
# Using TensorFlow backend.

# %%
# !ls checkpoints/
# Out:
# 201806162129_crnn_lstm_synthtext
# 201904020352_tbpp512_cocotext
# 201904020527_tbpp512_cocotext
# 201904020535_crnn_lstm_synthtext
# 201904020539_crnn_lstm_synthtext
# 201904020544_crnn_lstm_synthtext
# 201904020616_crnn_lstm_synthtext
# 201904020834_crnn_lstm_synthtext
# 201904020853_crnn_lstm_synthtext
# 201904020857_crnn_lstm_synthtext
# 201904030137_crnn_lstm_cocotext
# 201904030233_crnn_lstm_cocotext_256
# 201904030258_crnn_lstm_cocotext
# 201904030333_crnn_lstm_cocotext_pretrained
# 201904030354_crnn_lstm_cocotext_pretrained
# 201904030521_crnn_lstm_cocotext_pretrained
# 201904030524_crnn_lstm_cocotext_pretrained_v1
# 201904030550_crnn_lstm_cocotext_pretrained_v2
# 201904030644_crnn_lstm_cocotext_pretrained_v4
# 201904030700_crnn_lstm_cocotext_pretrained_v5
# 201904030850_crnn_lstm_cocotext_pretrained_v6
# 201904030853_crnn_lstm_cocotext_pretrained_v7
# 201904040443_crnn_lstm_cocotext
# 201904040450_crnn_lstm_cocotext_pretrained_v7
# 201904040628_crnn_lstm_cocotext_pretrained_v8
# 201904040750_crnn_lstm_cocotext_pretrained_v9
# 201904040752_crnn_lstm_cocotext_pretrained_v9

# %%
checkdir = '201904030524_crnn_lstm_cocotext_pretrained_v1'
plot_log(checkdir, ['loss'], None)
# Out:
# 201904030524_crnn_lstm_cocotext_pretrained_v1
# {'loss'}
# time per epoch 0.1 h

# %%
checkdir1 = './checkpoints/201806162129_crnn_lstm_synthtext'
checkdir2 = './checkpoints/201806190711_crnn_gru_synthtext'

plot_log(checkdir1+'/log.json', ['loss'], [0, np.inf], window_length=2000, log_file_compare=checkdir2+'/log.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-48776f9ab9ed> in <module>
#       2 checkdir2 = './checkpoints/201806190711_crnn_gru_synthtext'
#       3
# ----> 4 plot_log(checkdir1+'/log.json', ['loss'], [0, np.inf], window_length=2000, log_file_compare=checkdir2+'/log.json')
#
# TypeError: plot_log() got an unexpected keyword argument 'log_file_compare'
